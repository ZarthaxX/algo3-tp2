# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def correlacion_pearson(data_frame, columna1, columna2):
    return np.corrcoef(data_frame[columna1], data_frame[columna2])[0,1];

# %% [markdown]
# # Experimentos del TP de CMI

# %% [markdown]
# # Datasets
# Para los experimentos se crean las siguientes familias de instancias para evaluar los distintos métodos.
# 1. **Optimo**

# %% [markdown]
# # Métodos
# Los métodos evaluados en este notebook son los siguientes:
# - **GS**: Fuerza Bruta.
# - **GE**: Backtracking con podas por optimalidad y factibilidad.
# - **GB**:
# - **TS**: Tabu search.

# %% [markdown]
# # Experimentos
# Leemos el dataframe con todos los resultados.

# %%
df_resultados = pd.read_csv("..\\results\\resultado.csv");

# %%
df_resultados
# Out:
#                dataset   n   mG   mH  metodo  tiempo  impacto  cant_colores  \
# 0     random-ralo-ralo  10   20   20      GB   0.000      6.0           5.0
# 1     random-ralo-ralo  10   20   20      GB   0.000      7.0           4.0
# 2     random-ralo-ralo  10   20   20      GB   0.000      7.0           4.0
# 3     random-ralo-ralo  10   20   20      GB   0.928      6.0           4.0
# 4     random-ralo-ralo  10   20   20      GB   0.946      7.0           4.0
# ...                ...  ..  ...  ...     ...     ...      ...           ...
# 1247            optimo  26   98  103  OPTIMO   0.000     38.0           5.0
# 1248            optimo  28  106  117  OPTIMO   0.000     48.0           5.0
# 1249            optimo  30  137  128  OPTIMO   0.000     47.0           6.0
# 1250            optimo   6    7    2  OPTIMO   0.000      1.0           4.0
# 1251            optimo   8    8    8  OPTIMO   0.000      6.0           2.0
#
#       longitud_tabu tipo_memoria  porcentaje_vecindad
# 0                 0         none                    0
# 1                 0         none                    0
# 2                 0         none                    0
# 3                 0         none                    0
# 4                 0         none                    0
# ...             ...          ...                  ...
# 1247              0         none                    0
# 1248              0         none                    0
# 1249              0         none                    0
# 1250              0         none                    0
# 1251              0         none                    0
#
# [1252 rows x 11 columns]

# %% [markdown]
# ## Experimento 1: Heuristicas con optimo conocido

# %%
df_optimo_heuristicas = df_resultados[(df_resultados["metodo"]=="GS") |
                                      (df_resultados["metodo"]=="GE") |
                                      (df_resultados["metodo"]=="GB") |
                                      (df_resultados["metodo"]=="OPTIMO")
                                     ].copy();
df_optimo_heuristicas
# Out:
#    dataset   n   mG   mH  metodo  tiempo  impacto  cant_colores  \
# 0   optimo   6    7    2      GB   0.000      1.0           3.0
# 1   optimo   6    7    2      GE   0.000      1.0           3.0
# 2   optimo   6    7    2      GS   0.000      1.0           3.0
# 3   optimo   6    7    2  OPTIMO   0.000      1.0           4.0
# 4   optimo   8    8    8      GB   0.000      6.0           2.0
# 5   optimo   8    8    8      GE   0.000      5.0           3.0
# 6   optimo   8    8    8      GS   0.000      6.0           2.0
# 7   optimo   8    8    8  OPTIMO   0.000      6.0           2.0
# 8   optimo  10   20    5      GB   0.000      2.0           4.0
# 9   optimo  10   20    5      GE   0.000      2.0           4.0
# 10  optimo  10   20    5      GS   0.000      3.0           3.0
# 11  optimo  10   20    5  OPTIMO   0.000      3.0           7.0
# 12  optimo  12   16   26      GB   0.000     15.0           3.0
# 13  optimo  12   16   26      GE   0.000     13.0           3.0
# 14  optimo  12   16   26      GS   0.000      9.0           4.0
# 15  optimo  12   16   26  OPTIMO   0.000     16.0           3.0
# 16  optimo  14   29   25      GB   2.002     11.0           5.0
# 17  optimo  14   29   25      GE   0.000     11.0           5.0
# 18  optimo  14   29   25      GS   0.000     10.0           4.0
# 19  optimo  14   29   25  OPTIMO   0.000     12.0           5.0
# 20  optimo  16   35   43      GB   3.003     17.0           5.0
# 21  optimo  16   35   43      GE   0.000     15.0           5.0
# 22  optimo  16   35   43      GS   0.000     18.0           4.0
# 23  optimo  16   35   43  OPTIMO   0.000     20.0           4.0
# 24  optimo  18   41   54      GB   5.004     26.0           4.0
# 25  optimo  18   41   54      GE   0.000     24.0           4.0
# 26  optimo  18   41   54      GS   0.000     19.0           4.0
# 27  optimo  18   41   54  OPTIMO   0.000     27.0           4.0
# 28  optimo  20   57   51      GB   8.007     20.0           7.0
# 29  optimo  20   57   51      GE   0.000     16.0           5.0
# 30  optimo  20   57   51      GS   0.000     18.0           4.0
# 31  optimo  20   57   51  OPTIMO   0.000     25.0           5.0
# 32  optimo  22   77   58      GB  12.011     19.0           7.0
# 33  optimo  22   77   58      GE   0.000     24.0           6.0
# 34  optimo  22   77   58      GS   0.000     18.0           6.0
# 35  optimo  22   77   58  OPTIMO   0.000     26.0           6.0
# 36  optimo  24   79   72      GB  15.014     29.0           6.0
# 37  optimo  24   79   72      GE   0.000     23.0           6.0
# 38  optimo  24   79   72      GS   0.000     20.0           5.0
# 39  optimo  24   79   72  OPTIMO   0.000     33.0           5.0
# 40  optimo  26   98  103      GB  26.023     37.0           6.0
# 41  optimo  26   98  103      GE   0.000     31.0           7.0
# 42  optimo  26   98  103      GS   0.000     27.0           6.0
# 43  optimo  26   98  103  OPTIMO   0.000     38.0           5.0
# 44  optimo  28  106  117      GB  33.030     43.0           6.0
# 45  optimo  28  106  117      GE   0.000     40.0           6.0
# 46  optimo  28  106  117      GS   0.000     30.0           5.0
# 47  optimo  28  106  117  OPTIMO   0.000     48.0           5.0
# 48  optimo  30  137  128      GB  47.042     35.0           8.0
# 49  optimo  30  137  128      GE   0.000     38.0           6.0
# 50  optimo  30  137  128      GS   0.000     39.0           5.0
# 51  optimo  30  137  128  OPTIMO   0.000     47.0           6.0
#
#     longitud_tabu tipo_memoria  porcentaje_vecindad
# 0               0         none                    0
# 1               0         none                    0
# 2               0         none                    0
# 3               0         none                    0
# 4               0         none                    0
# 5               0         none                    0
# 6               0         none                    0
# 7               0         none                    0
# 8               0         none                    0
# 9               0         none                    0
# 10              0         none                    0
# 11              0         none                    0
# 12              0         none                    0
# 13              0         none                    0
# 14              0         none                    0
# 15              0         none                    0
# 16              0         none                    0
# 17              0         none                    0
# 18              0         none                    0
# 19              0         none                    0
# 20              0         none                    0
# 21              0         none                    0
# 22              0         none                    0
# 23              0         none                    0
# 24              0         none                    0
# 25              0         none                    0
# 26              0         none                    0
# 27              0         none                    0
# 28              0         none                    0
# 29              0         none                    0
# 30              0         none                    0
# 31              0         none                    0
# 32              0         none                    0
# 33              0         none                    0
# 34              0         none                    0
# 35              0         none                    0
# 36              0         none                    0
# 37              0         none                    0
# 38              0         none                    0
# 39              0         none                    0
# 40              0         none                    0
# 41              0         none                    0
# 42              0         none                    0
# 43              0         none                    0
# 44              0         none                    0
# 45              0         none                    0
# 46              0         none                    0
# 47              0         none                    0
# 48              0         none                    0
# 49              0         none                    0
# 50              0         none                    0
# 51              0         none                    0
